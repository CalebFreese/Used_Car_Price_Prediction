# %% [markdown]
# # Import Files

# %%
import sys
import os
import numpy as np

# Get the current working directory
current_directory = os.getcwd()

# Add the main folder to the sys.path list
main_folder_path = os.path.abspath(os.path.join(current_directory, '..'))
sys.path.append(main_folder_path)

from src.Models import Train_Model
from src.Models import Predict_Model
from src.Data import Make_Dataset_Functions as funs

# %% [markdown]
# # Get Data

# %%
#gets X_test data
file_path_read = os.path.join(current_directory, '..', 'Data', 'Processed', 'X_test.csv')
X_test = np.array(funs.read_processed(file_path_read))

#gets X_train data
file_path_read = os.path.join(current_directory, '..', 'Data', 'Processed', 'X_train.csv')
X_train = np.array(funs.read_processed(file_path_read))

#gets y_test data
file_path_read = os.path.join(current_directory, '..', 'Data', 'Processed', 'y_test.csv')
y_test = np.array(funs.read_processed(file_path_read))

#gets y_train data
file_path_read = os.path.join(current_directory, '..', 'Data', 'Processed', 'y_train.csv')
y_train = np.array(funs.read_y(file_path_read))

# %% [markdown]
# # Train Model

# %%
#get file name
file_path_NN = os.path.join(current_directory, '..', 'Models', 'Test Models', 'NN.pkl')

#create model
model = Train_Model.neural_network(X_train, y_train, X_test, y_test, 1000, file_path_NN)
# Out:
# Epoch 1/1000
# 242/242 [==============================] - 1s 2ms/step - loss: 11.5963 - val_loss: 2.4395
# Epoch 2/1000
# 242/242 [==============================] - 0s 2ms/step - loss: 2.0040 - val_loss: 1.7451
# Epoch 3/1000
# 242/242 [==============================] - 0s 2ms/step - loss: 1.5292 - val_loss: 1.4821
# Epoch 4/1000
# 242/242 [==============================] - 0s 2ms/step - loss: 1.3530 - val_loss: 1.3872
# Epoch 5/1000
# 242/242 [==============================] - 0s 2ms/step - loss: 1.2789 - val_loss: 1.3294
# Epoch 6/1000
# 242/242 [==============================] - 0s 2ms/step - loss: 1.2337 - val_loss: 1.2925
# Epoch 7/1000
# 242/242 [==============================] - 0s 1ms/step - loss: 1.2020 - val_loss: 1.2556
# Epoch 8/1000
# 242/242 [==============================] - 0s 2ms/step - loss: 1.1726 - val_loss: 1.2241
# Epoch 9/1000
# 242/242 [==============================] - 0s 2ms/step - loss: 1.1437 - val_loss: 1.1989
# Epoch 10/1000
# ...

# %% [markdown]
# # Get Predictions

# %%
predict = Predict_Model.predict(model, X_test, y_test)
# Out:
# 61/61 [==============================] - 0s 945us/step
# Root Mean Squared Error (RMSE): 0.7511573026941708
